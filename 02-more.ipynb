# %%
import pandas as pd

# %%
my_series = pd.Series(["banana", 42, True, 3.14])

# %%
my_series
# Out:
# 0    banana
# 1        42
# 2      True
# 3      3.14
# dtype: object

# %%
type(my_series)
# Out:
# pandas.core.series.Series

# %%
my_series = pd.Series(
    ["banana", 42, True, 3.14],
    index=["string", "integer", "boolean", "float"]
)
my_series
# Out:
# string     banana
# integer        42
# boolean      True
# float        3.14
# dtype: object

# %%
my_series.loc["string"]
# Out:
# 'banana'

# %%
my_series.loc["float"]
# Out:
# 3.14

# %%
type(my_series.loc["float"])
# Out:
# float

# %%
my_series.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniforge3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\miniforge3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniforge3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 my_series.loc[0]
#
# File ~\miniforge3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\miniforge3\lib\site-packages\pandas\core\indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
#    1201 self._validate_key(key, axis)
# -> 1202 return self._get_label(key, axis=axis)
#
# File ~\miniforge3\lib\site-packages\pandas\core\indexing.py:1153, in _LocIndexer._get_label(self, label, axis)
#    1151 def _get_label(self, label, axis: int):
#    1152     # GH#5667 this will fail if the label is not present in the axis.
# -> 1153     return self.obj.xs(label, axis=axis)
#
# File ~\miniforge3\lib\site-packages\pandas\core\generic.py:3864, in NDFrame.xs(self, key, axis, level, drop_level)
#    3862             new_index = index[loc]
#    3863 else:
# -> 3864     loc = index.get_loc(key)
#    3866     if isinstance(loc, np.ndarray):
#    3867         if loc.dtype == np.bool_:
#
# File ~\miniforge3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 0

# %%
my_series.iloc[0]
# Out:
# 'banana'

# %%
scientists = pd.DataFrame(
    data={'Occupation':['Chemist','Statistician'],
          'Born':['1920-07-25', '1876-06-13'],
          'Died':['1958-04-16', '1937-10-16'],
          'Age':[37,61]},
    index=['Rosaline Franklin','William Gosset'],
    columns=['Age', 'Occupation', 'Born','Died'])
scientists
# Out:
#                    Age    Occupation        Born        Died
# Rosaline Franklin   37       Chemist  1920-07-25  1958-04-16
# William Gosset      61  Statistician  1876-06-13  1937-10-16

# %%
{"name": "daniel", "lname": "chen"}
# Out:
# {'name': 'daniel', 'lname': 'chen'}

# %%
scientists = pd.read_csv("data/scientists.csv")

# %%
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
scientists["Age"]
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
scientists.Age
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
ages = scientists.Age
ages
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
ages.shape
# Out:
# (8,)

# %%
ages.describe()
# Out:
# count     8.000000
# mean     59.125000
# std      18.325918
# min      37.000000
# 25%      44.000000
# 50%      58.500000
# 75%      68.750000
# max      90.000000
# Name: Age, dtype: float64

# %%
ages.mean()
# Out:
# 59.125

# %%
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
ages > ages.mean()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool

# %%
scientists.loc[ages > ages.mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
scientists.loc[ages > ages.mean() and ages < 75]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 scientists.loc[ages > ages.mean() and ages < 75]
#
# File ~\miniforge3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
scientists.loc[ages > ages.mean() & ages < 75]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\miniforge3\lib\site-packages\pandas\core\ops\array_ops.py:301, in na_logical_op(x, y, op)
#     292 try:
#     293     # For exposition, write:
#     294     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     299     # Then Cases where this goes through without raising include:
#     300     #  (xint or xbool) and (yint or bool)
# --> 301     result = op(x, y)
#     302 except TypeError:
#
# File ~\miniforge3\lib\site-packages\pandas\core\roperator.py:52, in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\miniforge3\lib\site-packages\pandas\core\ops\array_ops.py:315, in na_logical_op(x, y, op)
#     314 try:
# --> 315     result = libops.scalar_binop(x, y, op)
#     316 except (
#     317     TypeError,
#     318     ValueError,
#    (...)
#     321     NotImplementedError,
#     322 ) as err:
#
# File ~\miniforge3\lib\site-packages\pandas\_libs\ops.pyx:180, in pandas._libs.ops.scalar_binop()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'long long'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 scientists.loc[ages > ages.mean() & ages < 75]
#
# File ~\miniforge3\lib\site-packages\pandas\core\generic.py:2101, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2097 @final
#    2098 def __array_ufunc__(
#    2099     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2100 ):
# -> 2101     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~\miniforge3\lib\site-packages\pandas\core\arraylike.py:263, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     260     return result
#     262 # for binary ops, use our custom dunder methods
# --> 263 result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#     264 if result is not NotImplemented:
#     265     return result
#
# File ~\miniforge3\lib\site-packages\pandas\_libs\ops_dispatch.pyx:113, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# File ~\miniforge3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\miniforge3\lib\site-packages\pandas\core\arraylike.py:74, in OpsMixin.__rand__(self, other)
#      72 @unpack_zerodim_and_defer("__rand__")
#      73 def __rand__(self, other):
# ---> 74     return self._logical_method(other, roperator.rand_)
#
# File ~\miniforge3\lib\site-packages\pandas\core\series.py:5634, in Series._logical_method(self, other, op)
#    5631 lvalues = self._values
#    5632 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5634 res_values = ops.logical_op(lvalues, rvalues, op)
#    5635 return self._construct_result(res_values, name=res_name)
#
# File ~\miniforge3\lib\site-packages\pandas\core\ops\array_ops.py:391, in logical_op(left, right, op)
#     387 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     388 #   integer dtypes.  Otherwise these are boolean ops
#     389 filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# --> 391 res_values = na_logical_op(lvalues, rvalues, op)
#     392 # error: Cannot call function of unknown type
#     393 res_values = filler(res_values)  # type: ignore[operator]
#
# File ~\miniforge3\lib\site-packages\pandas\core\ops\array_ops.py:324, in na_logical_op(x, y, op)
#     316         except (
#     317             TypeError,
#     318             ValueError,
#    (...)
#     321             NotImplementedError,
#     322         ) as err:
#     323             typ = type(y).__name__
# --> 324             raise TypeError(
#     325                 f"Cannot perform '{op.__name__}' with a dtyped [{x.dtype}] array "
#     326                 f"and scalar of type [{typ}]"
#     327             ) from err
#     329 return result.reshape(x.shape)
#
# TypeError: Cannot perform 'rand_' with a dtyped [int64] array and scalar of type [bool]

# %%
scientists.loc[(ages > ages.mean()) & (ages < 75)]
# Out:
#              Name        Born        Died  Age    Occupation
# 1  William Gosset  1876-06-13  1937-10-16   61  Statistician
# 3     Marie Curie  1867-11-07  1934-07-04   66       Chemist

# %%
scientists.loc[(ages > ages.mean()) | (ages < 75)]
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
scientists.loc[(ages > ages.mean()) & !(ages < 75)]
# Out:
#   Input In [42]
#     scientists.loc[(ages > ages.mean()) & !(ages < 75)]
#                                           ^
# SyntaxError: invalid syntax

# %%
scientists.loc[(ages > ages.mean()) & ~(ages < 75)]
# Out:
#                    Name        Born        Died  Age     Occupation
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
ages
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
scientists.loc[(scientists.Age > scientists.Age.mean()) & ~(scientists.Age < 75), :]
# Out:
#                    Name        Born        Died  Age     Occupation
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
scientists.loc[(scientists.Age > scientists.Age.mean()) & ~(scientists.Age < 75), ["Name", "Age"]]
# Out:
#                    Name  Age
# 2  Florence Nightingale   90
# 7          Johann Gauss   77

# %%
scientists.dtypes
# Out:
# Name          object
# Born          object
# Died          object
# Age            int64
# Occupation    object
# dtype: object

# %%
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
pd.to_datetime(scientists["Born"], format="%Y-%m-%d").dt.year
# Out:
# 0    1920
# 1    1876
# 2    1820
# 3    1867
# 4    1907
# 5    1813
# 6    1912
# 7    1777
# Name: Born, dtype: int64

# %%
scientists["born_dt"] = pd.to_datetime(scientists["Born"], format="%Y-%m-%d")

# %%
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt
# 0 1920-07-25
# 1 1876-06-13
# 2 1820-05-12
# 3 1867-11-07
# 4 1907-05-27
# 5 1813-03-15
# 6 1912-06-23
# 7 1777-04-30

# %%
sub = scientists.loc[scientists.Age < 60]
sub
# Out:
#                 Name        Born        Died  Age          Occupation  \
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 4      Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5          John Snow  1813-03-15  1858-06-16   45           Physician
# 6        Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
#
#      born_dt
# 0 1920-07-25
# 4 1907-05-27
# 5 1813-03-15
# 6 1912-06-23

# %%
sub["died_dt"] =  pd.to_datetime(scientists["Died"], format="%Y-%m-%d")
# Out:
# C:\Users\Danie\AppData\Local\Temp\ipykernel_20540\3154232017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub["died_dt"] =  pd.to_datetime(scientists["Died"], format="%Y-%m-%d")

# %%
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt
# 0 1920-07-25
# 1 1876-06-13
# 2 1820-05-12
# 3 1867-11-07
# 4 1907-05-27
# 5 1813-03-15
# 6 1912-06-23
# 7 1777-04-30

# %%
sub
# Out:
#                 Name        Born        Died  Age          Occupation  \
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 4      Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5          John Snow  1813-03-15  1858-06-16   45           Physician
# 6        Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
#
#      born_dt    died_dt
# 0 1920-07-25 1958-04-16
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07

# %%
sub = scientists.loc[scientists.Age < 60].copy()
sub["died_dt"] =  pd.to_datetime(scientists["Died"], format="%Y-%m-%d")
sub
# Out:
#                 Name        Born        Died  Age          Occupation  \
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 4      Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5          John Snow  1813-03-15  1858-06-16   45           Physician
# 6        Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
#
#      born_dt    died_dt
# 0 1920-07-25 1958-04-16
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07

# %%
scientists.to_csv("scientists_out.csv", index=False)

# %%
scientists.to_csv("scientists_out.csv")

# %%
reload = pd.read_csv("scientists_out.csv")
reload
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#       born_dt
# 0  1920-07-25
# 1  1876-06-13
# 2  1820-05-12
# 3  1867-11-07
# 4  1907-05-27
# 5  1813-03-15
# 6  1912-06-23
# 7  1777-04-30

# %%
scientists.to_json()
# Out:
# '{"Name":{"0":"Rosaline Franklin","1":"William Gosset","2":"Florence Nightingale","3":"Marie Curie","4":"Rachel Carson","5":"John Snow","6":"Alan Turing","7":"Johann Gauss"},"Born":{"0":"1920-07-25","1":"1876-06-13","2":"1820-05-12","3":"1867-11-07","4":"1907-05-27","5":"1813-03-15","6":"1912-06-23","7":"1777-04-30"},"Died":{"0":"1958-04-16","1":"1937-10-16","2":"1910-08-13","3":"1934-07-04","4":"1964-04-14","5":"1858-06-16","6":"1954-06-07","7":"1855-02-23"},"Age":{"0":37,"1":61,"2":90,"3":66,"4":56,"5":45,"6":41,"7":77},"Occupation":{"0":"Chemist","1":"Statistician","2":"Nurse","3":"Chemist","4":"Biologist","5":"Physician","6":"Computer Scientist","7":"Mathematician"},"born_dt":{"0":-1560124800000,"1":-2952201600000,"2":-4722192000000,"3":-3223584000000,"4":-1975536000000,"5":-4948128000000,"6":-1815350400000,"7":-6080140800000}}'

# %%
scientists.to_json("scientists_out.json", orient="table", indent=2)
